# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/DISE-O2025/blob/main/SEGUNDOSEMESTRE2025_Corte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Informe de la Coordinación de Matemáticas y Estadística -202510**

# %% [markdown]
# <a name="inicio"></a>
#
#
# ## **1.** [La Dirección](#T1)
# ## **2.** [El Coordinador](#T2)
#
# ## **3.** [Calendario Academico](#T3)
#
# ## **4.** [Librerias de Analisis](#T4)
#
# ## **5.** [Cambiando el Archivo Excel a csv](#T5)
#
# ## **6.** [Resultados Generales 202520 - Corte 1](#T6)
#
# ## **7.** [Resultados Generales por Docentes](#T7)
#
#
# ## **8.** [Resultados por Docente vs Asignaturas](#T8)
#
# ## **9.** [Resultados por Programas vs Asignaturas](#T9)
#
#
# ## **10.** [](#T10)
#
# ## **11.** [](#T11)
#
# ## **12.** [](#T12)

# %% [markdown]
# <a name="ultimo1"></a>

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# ## **1. La Dirección**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T2"></a>
# ## **2. El Coordinador**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T3"></a>
# ## **3. Calendario Academico 2025 - 20**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T4"></a>
# ## **4. Librerias de Analisis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
# !pip install bioinfokit &>/dev/null
from bioinfokit.analys import stat
from statsmodels.graphics.factorplots import interaction_plot

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T5"></a>
# ## **5. Cambiando el Archivo Excel a csv**

# %%
# @title **A. Cambiando el Archivo Excel a csv**
excel_file_path = "/content/BAN - Reporte de Notas Parciales general - Mats y Est.xlsx"
datos = pd.read_excel(excel_file_path)

# Save the DataFrame to a CSV file
csv_file_path = "datos.csv"
datos.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")

# Display the first few rows of the DataFrame
display(datos.head())
# Out:
# Data saved to datos.csv
#   Id_estudiante Apellidos_estudiante Nombres_estudiante  \
# 0     T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 1     T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 2     T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 3     T00023471     RODRIGUEZ ROMERO              RUDDY
# 4     T00023471     RODRIGUEZ ROMERO              RUDDY
#
#           Situacion_academica Becas                  Email     Telefono  \
# 0  SITUACION ACADEMICA NORMAL   NaN    larroyo19@gmail.com   3002033150
# 1  SITUACION ACADEMICA NORMAL   NaN    larroyo19@gmail.com   3002033150
# 2  SITUACION ACADEMICA NORMAL   NaN    larroyo19@gmail.com   3002033150
# 3                         NaN   NaN  ruddy0101@hotmail.com  605-6634080
# 4                         NaN   NaN  ruddy0101@hotmail.com  605-6634080
#
#          Celular                              Programa Cod_prog  ...  \
# 0  57-3002033150                                DISEÑO       54  ...
# ...

# %%
# @title **B. Los datos Preparados**
datos = pd.read_csv("/content/datos.csv")
datos
# Out:
#      Id_estudiante Apellidos_estudiante Nombres_estudiante  \
# 0        T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 1        T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 2        T00018314       ARROYO ALCIRIA       LUIS EDUARDO
# 3        T00023471     RODRIGUEZ ROMERO              RUDDY
# 4        T00023471     RODRIGUEZ ROMERO              RUDDY
# ...            ...                  ...                ...
# 9781     T00096359      NARANJO TEDESCO           GIANLUCA
# 9782     T00096359      NARANJO TEDESCO           GIANLUCA
# 9783     T00096422       GUERRERO ERAZO         AURA SOFIA
# 9784     T00096422       GUERRERO ERAZO         AURA SOFIA
# 9785     T00096422       GUERRERO ERAZO         AURA SOFIA
#
#              Situacion_academica           Becas  \
# 0     SITUACION ACADEMICA NORMAL             NaN
# 1     SITUACION ACADEMICA NORMAL             NaN
# 2     SITUACION ACADEMICA NORMAL             NaN
# 3                            NaN             NaN
# ...

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# @title **C. Los datos Preparados**
datos.tail()
# Out:
#      Id_estudiante Apellidos_estudiante Nombres_estudiante  \
# 9781     T00096359      NARANJO TEDESCO           GIANLUCA
# 9782     T00096359      NARANJO TEDESCO           GIANLUCA
# 9783     T00096422       GUERRERO ERAZO         AURA SOFIA
# 9784     T00096422       GUERRERO ERAZO         AURA SOFIA
# 9785     T00096422       GUERRERO ERAZO         AURA SOFIA
#
#      Situacion_academica           Becas                         Email  \
# 9781                 NaN             NaN  gianlucanaranjo173@gmail.com
# 9782                 NaN             NaN  gianlucanaranjo173@gmail.com
# 9783                 NaN  DESCUENTO NEXO           achan0943@gmail.com
# 9784                 NaN  DESCUENTO NEXO           achan0943@gmail.com
# 9785                 NaN  DESCUENTO NEXO           achan0943@gmail.com
#
#         Telefono        Celular                             Programa Cod_prog  \
# 9781  3161002217            NaN  FINANZAS Y NEGOCIOS INTERNACIONALES       16
# ...

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# @title **D. Los datos Preparados**
datos.columns
# Out:
# Index(['Id_estudiante', 'Apellidos_estudiante', 'Nombres_estudiante',
#        'Situacion_academica', 'Becas', 'Email', 'Telefono', 'Celular',
#        'Programa', 'Cod_prog', 'Periodo', 'Cod_tipo', 'Tipo_estudiante', 'Nrc',
#        'Materia', 'Curso', 'Parte_periodo', 'Asignatura', 'Creditos', 'Sesion',
#        'Cod_estatus', 'Estatus', 'Cod_comp', 'Componente', 'Nota_parcial',
#        'Cod_subcomp', 'Subcomponente', 'Nota_parcial_subcomponente',
#        'Id_docente', 'Apellidos_docente', 'Nombres_docente',
#        'Nro_componentes'],
#       dtype='object')

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T6"></a>
# ## **6. Resultados Generales 202520 - Corte 1**

# %%
# @title **A. Resultados Generales -Diagrama de Barras**
import matplotlib.pyplot as plt
import seaborn as sns

# Melt the DataFrame to long format for easier plotting
tabla_melted = tabla_estadisticas.melt(
    id_vars='Asignatura',
    value_vars=['estudiantes_menor_2_95', 'estudiantes_mayor_2_95'],
    var_name='Grupo_Nota',
    value_name='Cantidad_Estudiantes'
)

# Create the grouped bar chart
plt.figure(figsize=(14, 8))
barplot = sns.barplot(x='Asignatura', y='Cantidad_Estudiantes', hue='Grupo_Nota', data=tabla_melted)

# Add the counts on top of the bars
for container in barplot.containers:
    barplot.bar_label(container, fmt='%d', label_type='edge')

plt.title('Resultados Primer Corte 202520 - Matemáticas Y Estadística')
plt.xlabel('Asignatura')
plt.ylabel('Número de Estudiantes')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
# @title **B. Resultados Generales -Diagrama de Barras**
import matplotlib.pyplot as plt
import seaborn as sns

# Melt the DataFrame to long format for easier plotting, using percentage columns
tabla_melted_percent = tabla_estadisticas.melt(
    id_vars='Asignatura',
    value_vars=['porcentaje_menor_2_95', 'porcentaje_mayor_2_95'],
    var_name='Grupo_Nota_Porcentaje',
    value_name='Porcentaje_Estudiantes'
)

# Create the grouped bar chart for percentages
plt.figure(figsize=(14, 8))
barplot_percent = sns.barplot(x='Asignatura', y='Porcentaje_Estudiantes', hue='Grupo_Nota_Porcentaje', data=tabla_melted_percent)

# Add the percentages on top of the bars
for container in barplot_percent.containers:
    barplot_percent.bar_label(container, fmt='%.1f%%', label_type='edge')

plt.title('Porcentaje Resultados Primer Corte 202520 - Matemáticas Y Estadística')
plt.xlabel('Asignatura')
plt.ylabel('Porcentaje de Estudiantes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# @title **B. Resultados Generales -Diagrama de caja y Bigotes**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from bioinfokit.analys import stat
from statsmodels.graphics.factorplots import interaction_plot


# Group the data by 'Asignatura'
asignaturas = datos['Asignatura'].unique()
n_asignaturas = len(asignaturas)
n_cols = 3  # Number of columns in the subplot grid

# Calculate the number of rows needed
n_rows = (n_asignaturas + n_cols - 1) // n_cols

# Create the subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
axes = axes.flatten()  # Flatten the axes array

for i, asignatura in enumerate(asignaturas):
    ax = axes[i]
    subset = datos[datos['Asignatura'] == asignatura]

    sns.boxplot(y="Nota_parcial", x="Componente", data=subset, ax=ax)

    mean_by_componente = subset.groupby('Componente')['Nota_parcial'].mean()

    for j, componente in enumerate(subset['Componente'].unique()):
        mean_value = mean_by_componente[componente]
        ax.text(j, mean_value, f'{mean_value:.2f}', ha='center', va='bottom', color='red', fontweight='bold')

    ax.set_title(f'Nota Parcial vs Componente - {asignatura}')
    ax.set_xlabel('Componente')
    ax.set_ylabel('Nota Parcial')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])


plt.tight_layout() # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
import numpy as np
# @title **B. Resultados Generales -Diagrama de caja y Bigotes**
# Calculate the required statistics for each Asignatura
tabla_estadisticas = datos.groupby('Asignatura')['Nota_parcial'].agg(
    promedio='mean',
    mediana='median',
    desviacion_estandar='std',
    minimo='min',
    maximo='max',
    cuartil_1=lambda x: np.quantile(x.dropna(), 0.25),
    cuartil_3=lambda x: np.quantile(x.dropna(), 0.75),
    estudiantes_menor_2_95=lambda x: (x < 2.95).sum(),
    estudiantes_mayor_2_95=lambda x: (x >= 2.95).sum() # Changed to >= 2.95 to include 2.95 in the count of students above 2.95
).reset_index()

# Calculate the total number of students
tabla_estadisticas['total_estudiantes'] = tabla_estadisticas['estudiantes_menor_2_95'] + tabla_estadisticas['estudiantes_mayor_2_95']

# Calculate the percentages
tabla_estadisticas['porcentaje_menor_2_95'] = (tabla_estadisticas['estudiantes_menor_2_95'] / tabla_estadisticas['total_estudiantes']) * 100
tabla_estadisticas['porcentaje_mayor_2_95'] = (tabla_estadisticas['estudiantes_mayor_2_95'] / tabla_estadisticas['total_estudiantes']) * 100


# Display the table
display(tabla_estadisticas)
# Out:
#                         Asignatura  promedio  mediana  desviacion_estandar  \
# 0                   ALGEBRA LINEAL  3.268369      3.3             0.854655
# 1              CALCULO DIFERENCIAL  2.600000      2.6             1.241461
# 2                 CALCULO INTEGRAL  3.065582      3.1             1.089556
# 3                CALCULO VECTORIAL  2.726603      2.8             0.959282
# 4    ECUACIONES DIFERENCIALES Y EN  3.191964      3.2             0.923860
# 5                    ESTADÍSTICA I  3.128205      3.4             1.098866
# 6                   ESTADÍSTICA II  3.225333      3.2             0.756609
# 7          ESTADÍSTICA INFERENCIAL  3.561818      3.7             0.906805
# 8       ESTADÍSTICA Y PROBABILIDAD  3.354520      3.6             1.048617
# 9                        GEOMETRÍA  3.321053      3.3             0.786398
# 10  MATEMÁTICA PARA CIENCIAS SOCIA  3.488889      3.7             1.101189
# ...

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T7"></a>
# ## **7. Resultados Generales por Docentes**

# %%
# @title **A. Resultados Generales por Docentes**

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'datos' DataFrame is already loaded as in the previous code

# Group docentes for the plot
num_groups = 5
docentes_per_group = len(datos['Apellidos_docente'].unique()) // num_groups
docente_groups = []
for i in range(num_groups):
    start_index = i * docentes_per_group
    end_index = (i + 1) * docentes_per_group if i < num_groups - 1 else len(datos['Apellidos_docente'].unique())
    docente_groups.append(datos['Apellidos_docente'].unique()[start_index:end_index])

fig, axes = plt.subplots(num_groups, 1, figsize=(20, 40))  # Adjust figure size as needed
fig.suptitle('Nota_parcial vs Apellidos_docente (grouped)', fontsize=16)

for i, group in enumerate(docente_groups):
    ax = axes[i]
    group_data = datos[datos['Apellidos_docente'].isin(group)]
    sns.boxplot(y="Apellidos_docente", x="Nota_parcial", hue='Componente', data=group_data, ax=ax)
    ax.set_title(f'Group {i+1}')

    mean_by_group = group_data.groupby('Apellidos_docente')['Nota_parcial'].mean()
    for j, docente in enumerate(group):
        mean_value = mean_by_group.get(docente, 0)  # Handle missing docentes
        ax.text(mean_value, j, f'{mean_value:.2f}', ha='left', va='center', color='red', fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95]) # Adjust layout to prevent overlapping
plt.show()

# %%
# @title **B. Resultados Generales por Docentes**
import numpy as np

# Calculate the required statistics for each teacher
tabla_estadisticas_docente = datos.groupby('Apellidos_docente')['Nota_parcial'].agg(
    promedio='mean',
    mediana='median',
    desviacion_estandar='std',
    minimo='min',
    maximo='max',
    cuartil_1=lambda x: np.quantile(x.dropna(), 0.25),
    cuartil_3=lambda x: np.quantile(x.dropna(), 0.75),
    estudiantes_menor_2_95=lambda x: (x < 2.95).sum(),
    estudiantes_mayor_2_95=lambda x: (x >= 2.95).sum()
).reset_index()

# Calculate the total number of students for each teacher
tabla_estadisticas_docente['total_estudiantes'] = tabla_estadisticas_docente['estudiantes_menor_2_95'] + tabla_estadisticas_docente['estudiantes_mayor_2_95']

# Calculate the percentages for each teacher
tabla_estadisticas_docente['porcentaje_menor_2_95'] = (tabla_estadisticas_docente['estudiantes_menor_2_95'] / tabla_estadisticas_docente['total_estudiantes']) * 100
tabla_estadisticas_docente['porcentaje_mayor_2_95'] = (tabla_estadisticas_docente['estudiantes_mayor_2_95'] / tabla_estadisticas_docente['total_estudiantes']) * 100

# Display the table
display(tabla_estadisticas_docente)
# Out:
#      Apellidos_docente  promedio  mediana  desviacion_estandar  minimo  \
# 0        AHUMADA SILVA  3.344248     3.40             0.684515     0.5
# 1    ATENCIO CONTRERAS  3.579310     4.00             1.082110     0.2
# 2        BARCO LLERENA  3.641111     3.70             0.787100     0.5
# 3    BARRIOS HERNANDEZ  3.752880     3.90             1.051455     0.5
# 4     CABARCAS URRIOLA  3.328662     3.30             0.556322     0.5
# 5        CARDONA GOMEZ  3.079167     3.25             1.020372     0.5
# 6    CASTILLO MARTINEZ  2.406481     2.50             0.758167     0.8
# 7        CASTRO GARCES  1.870796     1.70             1.089371     0.5
# 8         COHEN TORRES  2.935294     3.00             0.969500     0.5
# 9     ESCORCIA ESPITIA  2.723377     2.60             1.038204     0.5
# 10     GOMEZ FERNANDEZ  3.165000     3.30             0.930250     0.5
# 11  HERNANDEZ DEL TORO  3.546914     3.70             0.948958     0.5
# ...

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T8"></a>
# ## **8. Resultados por Docente vs Asignaturas**

# %%
# @title **A. Resultados por Docente vs Asignaturas**
mean_by_group = datos.groupby('Asignatura')['Nota_parcial'].mean()

# Group data by Apellidos_docente and create separate box plots
for apellido, group_data in datos.groupby('Apellidos_docente'):
  fig, ax = plt.subplots(figsize=(10, 6))
  ax.set_title(f'Nota_parcial vs Asignatura for {apellido}')
  sns.boxplot(y="Asignatura", x="Nota_parcial", hue='Componente', data=group_data, ax=ax)

  # Calculate the mean for each group within the current apellido group
  mean_by_group = group_data.groupby('Asignatura')['Nota_parcial'].mean()

  # Add the mean values to the plot
  for i, asignatura in enumerate(group_data['Asignatura'].unique()):
    mean_value = mean_by_group[asignatura]
    ax.text(mean_value, i, f'{mean_value:.2f}', ha='left', va='center', color='red', fontweight='bold')

  plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# @title **B. Resultados por Docente vs Asignaturas**
import numpy as np

# Calculate the required statistics for each combination of Docente, Asignatura, and Nrc
tabla_estadisticas_docente_asignatura_nrc = datos.groupby(['Apellidos_docente', 'Asignatura', 'Nrc'])['Nota_parcial'].agg(
    promedio='mean',
    mediana='median',
    desviacion_estandar='std',
    minimo='min',
    maximo='max',
    cuartil_1=lambda x: np.quantile(x.dropna(), 0.25),
    cuartil_3=lambda x: np.quantile(x.dropna(), 0.75),
    estudiantes_menor_2_95=lambda x: (x < 2.95).sum(),
    estudiantes_mayor_2_95=lambda x: (x >= 2.95).sum()
).reset_index()

# Calculate the total number of students
tabla_estadisticas_docente_asignatura_nrc['total_estudiantes'] = tabla_estadisticas_docente_asignatura_nrc['estudiantes_menor_2_95'] + tabla_estadisticas_docente_asignatura_nrc['estudiantes_mayor_2_95']

# Calculate the percentages
tabla_estadisticas_docente_asignatura_nrc['porcentaje_menor_2_95'] = (tabla_estadisticas_docente_asignatura_nrc['estudiantes_menor_2_95'] / tabla_estadisticas_docente_asignatura_nrc['total_estudiantes']) * 100
tabla_estadisticas_docente_asignatura_nrc['porcentaje_mayor_2_95'] = (tabla_estadisticas_docente_asignatura_nrc['estudiantes_mayor_2_95'] / tabla_estadisticas_docente_asignatura_nrc['total_estudiantes']) * 100


# Display the table
display(tabla_estadisticas_docente_asignatura_nrc)
# Out:
#       Apellidos_docente                      Asignatura   Nrc  promedio  \
# 0         AHUMADA SILVA                  ALGEBRA LINEAL  2293  3.247059
# 1         AHUMADA SILVA                CALCULO INTEGRAL  1221  3.360000
# 2         AHUMADA SILVA                CALCULO INTEGRAL  2131  3.412821
# 3     ATENCIO CONTRERAS                   ESTADÍSTICA I  1003  3.566667
# 4     ATENCIO CONTRERAS                   ESTADÍSTICA I  1253  2.725000
# 5     ATENCIO CONTRERAS                   ESTADÍSTICA I  1271  3.240000
# 6     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1002  3.315385
# 7     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1252  3.432000
# 8     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1270  4.233333
# 9         BARCO LLERENA                  ESTADÍSTICA II  1251  3.366667
# 10        BARCO LLERENA                  ESTADÍSTICA II  1281  3.400000
# 11        BARCO LLERENA                  ESTADÍSTICA II  1299  3.966667
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get unique teacher last names
docentes = datos['Apellidos_docente'].unique()

# Generate a report for each teacher
for docente in docentes:
    # Filter data for the current teacher
    datos_docente = datos[datos['Apellidos_docente'] == docente]

    # Create a box plot for the teacher
    plt.figure(figsize=(12, 6))
    sns.boxplot(y='Asignatura', x='Nota_parcial', hue='Nrc', data=datos_docente) # Changed hue to 'Nrc'
    plt.title(f'Nota Parcial por Asignatura y NRC para el Docente: {docente}') # Updated title
    plt.xlabel('Nota Parcial')
    plt.ylabel('Asignatura')
    plt.grid(True)
    plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# @title **C. Resultados por Docente vs Asignaturas**

import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(tabla_estadisticas_docente_asignatura_nrc)
# Out:
#       Apellidos_docente                      Asignatura   Nrc  promedio  \
# 0         AHUMADA SILVA                  ALGEBRA LINEAL  2293  3.247059
# 1         AHUMADA SILVA                CALCULO INTEGRAL  1221  3.360000
# 2         AHUMADA SILVA                CALCULO INTEGRAL  2131  3.412821
# 3     ATENCIO CONTRERAS                   ESTADÍSTICA I  1003  3.566667
# 4     ATENCIO CONTRERAS                   ESTADÍSTICA I  1253  2.725000
# 5     ATENCIO CONTRERAS                   ESTADÍSTICA I  1271  3.240000
# 6     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1002  3.315385
# 7     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1252  3.432000
# 8     ATENCIO CONTRERAS      ESTADÍSTICA Y PROBABILIDAD  1270  4.233333
# 9         BARCO LLERENA                  ESTADÍSTICA II  1251  3.366667
# 10        BARCO LLERENA                  ESTADÍSTICA II  1281  3.400000
# 11        BARCO LLERENA                  ESTADÍSTICA II  1299  3.966667
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get unique teacher last names
docentes = tabla_estadisticas_docente_asignatura_nrc['Apellidos_docente'].unique()

# Iterate through each teacher
for docente in docentes:
    # Filter data for the current teacher
    group_data = tabla_estadisticas_docente_asignatura_nrc[tabla_estadisticas_docente_asignatura_nrc['Apellidos_docente'] == docente].copy()

    # Melt the DataFrame to long format for easier plotting
    group_data_melted = group_data.melt(
        id_vars=['Apellidos_docente', 'Asignatura', 'Nrc'],
        value_vars=['estudiantes_menor_2_95', 'estudiantes_mayor_2_95'],
        var_name='Grupo_Nota',
        value_name='Cantidad_Estudiantes'
    )

    # Create a combined column for x-axis labels
    group_data_melted['Asignatura_NRC'] = group_data_melted['Asignatura'] + ' (' + group_data_melted['Nrc'].astype(str) + ')'

    # Create the grouped bar chart for the current teacher
    plt.figure(figsize=(12, 6))
    barplot = sns.barplot(
        x='Asignatura_NRC',
        y='Cantidad_Estudiantes',
        hue='Grupo_Nota',
        data=group_data_melted,
        palette={'estudiantes_menor_2_95': 'salmon', 'estudiantes_mayor_2_95': 'lightgreen'},
        errorbar=None # Remove error bars
    )

    # Add the counts on top of the bars
    for container in barplot.containers:
        barplot.bar_label(container, fmt='%d', label_type='edge')

    plt.title(f'Número de Estudiantes (< 2.95 vs >= 2.95) por Asignatura y NRC\nDocente: {docente}') # Add title for the individual teacher
    plt.xlabel('Asignatura (NRC)')
    plt.ylabel('Cantidad de Estudiantes')
    plt.xticks(rotation=90, ha='right') # Rotate x-axis labels for better readability
    plt.tight_layout()
    plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T9"></a>
# ## **9. Resultados por Programas vs Asignaturas**

# %%
# @title **A. Resultados por Programas vs Asignaturas**

# Group data by Apellidos_docente and create separate box plots
for apellido, group_data in datos.groupby('Programa'):
  fig, ax = plt.subplots(figsize=(10, 6))
  ax.set_title(f'Nota_parcial vs Asignatura for {apellido}')
  sns.boxplot(y="Asignatura", x="Nota_parcial", hue='Componente', data=group_data, ax=ax)

  # Calculate the mean for each group within the current apellido group
  mean_by_group = group_data.groupby('Asignatura')['Nota_parcial'].mean()

  # Add the mean values to the plot
  for i, asignatura in enumerate(group_data['Asignatura'].unique()):
    mean_value = mean_by_group[asignatura]
    ax.text(mean_value, i, f'{mean_value:.2f}', ha='left', va='center', color='red', fontweight='bold')

  plt.show()

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %%
# @title **B. Resultados por Programas vs Asignaturas**
import numpy as np

# Calculate the required statistics for each combination of Programa and Asignatura
tabla_estadisticas_programa_asignatura = datos.groupby(['Programa', 'Asignatura'])['Nota_parcial'].agg(
    promedio='mean',
    mediana='median',
    desviacion_estandar='std',
    minimo='min',
    maximo='max',
    cuartil_1=lambda x: np.quantile(x.dropna(), 0.25),
    cuartil_3=lambda x: np.quantile(x.dropna(), 0.75),
    estudiantes_menor_2_95=lambda x: (x < 2.95).sum(),
    estudiantes_mayor_2_95=lambda x: (x >= 2.95).sum()
).reset_index()

# Calculate the total number of students for each combination
tabla_estadisticas_programa_asignatura['total_estudiantes'] = tabla_estadisticas_programa_asignatura['estudiantes_menor_2_95'] + tabla_estadisticas_programa_asignatura['estudiantes_mayor_2_95']

# Calculate the percentages for each combination
tabla_estadisticas_programa_asignatura['porcentaje_menor_2_95'] = (tabla_estadisticas_programa_asignatura['estudiantes_menor_2_95'] / tabla_estadisticas_programa_asignatura['total_estudiantes']) * 100
tabla_estadisticas_programa_asignatura['porcentaje_mayor_2_95'] = (tabla_estadisticas_programa_asignatura['estudiantes_mayor_2_95'] / tabla_estadisticas_programa_asignatura['total_estudiantes']) * 100

# Display the table
display(tabla_estadisticas_programa_asignatura)
# Out:
#                                           Programa  \
# 0                       ADMINISTRACION DE EMPRESAS
# 1                       ADMINISTRACION DE EMPRESAS
# 2                       ADMINISTRACION DE EMPRESAS
# 3                       ADMINISTRACION DE EMPRESAS
# 4                       ADMINISTRACION DE EMPRESAS
# 5                       ADMINISTRACION DE EMPRESAS
# 6                                     ARQUITECTURA
# 7                                 CIENCIA DE DATOS
# 8                                 CIENCIA DE DATOS
# 9                                 CIENCIA DE DATOS
# 10                                CIENCIA DE DATOS
# 11                                CIENCIA DE DATOS
# 12                                CIENCIA DE DATOS
# 13                                CIENCIA DE DATOS
# 14   CIENCIA POLITICA Y RELACIONES INTERNACIONALES
# 15   CIENCIA POLITICA Y RELACIONES INTERNACIONALES
# 16   CIENCIA POLITICA Y RELACIONES INTERNACIONALES
# ...

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T10"></a>
# ## **10. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T11"></a>
# ## **11. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T12"></a>
# ## **12. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T13"></a>
# ## **13. **

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio3](#inicio3)
#
# [⬆️ Volver al ultimo3](#ultimo3)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="ultimo31"></a>
# ## **Este es el Ultimo Del Codigo**

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)
